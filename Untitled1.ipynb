# %%
import numpy as np
import pickle
import mne
import matplotlib.pyplot as plt

# %%
LVLA=np.load('output_layer_data1.npy')

# %%
LVLA_mean=np.mean(LVLA, axis=1)
LVLA.shape[1.3600, 2.2700][2.0600, 8.1500][9.0000, 7.9500]
# Out:
# (32, 128)

# %%
biosemi_montage = mne.channels.make_standard_montage('standard_1020')
ch_names = ['Fp1', 'AF3', 'F7', 'F3', 'FC1', 'FC5', 'T7', 'C3', 'CP1', 'CP5',
    'P7', 'P3', 'Pz', 'PO3', 'O1', 'Oz', 'O2', 'PO4', 'P4', 'P8',
    'CP6', 'CP2', 'C4', 'T8', 'FC6', 'FC2', 'F4', 'F8', 'AF4', 'Fp2',
    'Fz', 'Cz']
# band_list=[r'$\theta$', r'$\alpha$', r'$\beta$' , r'$\gamma$']
fig, axes = plt.subplots(figsize=(16, 10), nrows=1, ncols=4)
fig.suptitle('CompareALL')# 'HVLA','LVHA',
classes = ['LVLA', 'HVLA','LVHA','HVHA']
# 找出所有数据中的最小值和最大值
all_data = [np.load(f'Topo_data/s01_{classes[classe]}.npy') for classe in range(4)]
all_data_means = [np.mean(data, axis=1) for data in all_data]
vmin = min([data.min() for data in all_data_means])
vmax = max([data.max() for data in all_data_means])


for classe in range(4):
    data = np.load(f'Topo_data/s01_{classes[classe]}.npy')
    print(data)
    info = mne.create_info(ch_names=ch_names, sfreq=128., ch_types='eeg')
    evoked = mne.EvokedArray(data, info)
    evoked.set_montage(biosemi_montage)
    ax=axes[classe]
    mne.viz.plot_topomap(np.mean(evoked.data, axis=1), evoked.info, show=False, axes=ax,
                         ch_type='eeg', cmap='Spectral_r', contours=10, )#vlim=(vmin, vmax),
    ax.set_title(f'{classes[classe]}', fontsize=10)

fig.tight_layout()
plt.show()
# Out:
# [[-9.4831608e-02 -1.1104366e-01 -1.4430508e-01 ... -9.8354913e-02
#    1.0665722e-01 -5.9684001e-02]
#  [-2.7269285e-02 -4.7113962e-02 -5.4497313e-02 ...  8.6960785e-02
#    8.3441687e-01  8.3225548e-02]
#  [ 1.2196527e+00  8.8038999e-01  2.2244768e+00 ...  2.5031250e+00
#    4.3054957e+00  3.3452010e-01]
#  ...
#  [-2.9601919e-02  9.8722741e-02  3.5953170e-01 ...  6.4655887e-03
#    1.7803389e+00  8.5860066e-02]
#  [ 1.0865030e+00  8.3063436e-01  1.9886351e+00 ...  2.4146283e+00
#    2.9149988e+00  1.1613610e+00]
#  [ 6.1905451e+00  5.7897892e+00  6.5988750e+00 ...  5.6291618e+00
#    1.0386590e+01  4.4483805e+00]]
# [[-9.4831608e-02 -1.1104366e-01 -1.4430508e-01 ... -9.8354913e-02
#    1.0665722e-01 -5.9684001e-02]
#  [-2.7269285e-02 -4.7113962e-02 -5.4497313e-02 ...  8.6960785e-02
#    8.3441687e-01  8.3225548e-02]
#  [ 1.2196527e+00  8.8038999e-01  2.2244768e+00 ...  2.5031250e+00
#    4.3054957e+00  3.3452010e-01]
#  ...
#  [-2.9601919e-02  9.8722741e-02  3.5953170e-01 ...  6.4655887e-03
#    1.7803389e+00  8.5860066e-02]
#  [ 1.0865030e+00  8.3063436e-01  1.9886351e+00 ...  2.4146283e+00
#    2.9149988e+00  1.1613610e+00]
#  [ 6.1905451e+00  5.7897892e+00  6.5988750e+00 ...  5.6291618e+00
#    1.0386590e+01  4.4483805e+00]]
# [[-0.11861861 -0.14145808 -0.14074387 ... -0.18313792 -0.14887497
#   -0.09215565]
#  [ 0.13524428 -0.08296683 -0.06040109 ... -0.07452358  1.3171439
#   -0.06383094]
#  [ 1.5278318   0.9066844   2.070546   ...  2.468469    3.1343992
#    0.2720145 ]
#  ...
#  [-0.02294777  0.13007428  0.51582146 ...  0.05973038  3.0579588
#    0.5067814 ]
#  [ 3.096284    2.8544123   4.176404   ...  2.583251    4.550569
#    2.923422  ]
#  [ 6.7939324   6.7004867   5.8818426  ...  4.4793606   8.402538
#    5.369056  ]]
# [[-0.11637641 -0.15598825  1.8205059  ... -0.12513079  1.3436445
#   -0.11570355]
#  [-0.04747723 -0.07686099  0.82089573 ... -0.07501352  1.3975224
#   -0.0602501 ]
#  [-0.03073999 -0.06855655  2.660874   ...  1.2416255   1.932747
#   -0.05511502]
#  ...
#  [ 0.27866665 -0.04742291  1.8729701  ...  0.7659002   2.3038037
#    0.24208769]
#  [ 0.08140606  0.19686101  0.32584667 ...  0.7199547   2.3151188
#    0.5586484 ]
#  [ 3.9866123   4.9813643   2.4564927  ...  3.8719585   9.243824
#    3.5547564 ]]

# %%
biosemi_montage = mne.channels.make_standard_montage('standard_1020')
ch_names = ['Fp1', 'AF3', 'F7', 'F3', 'FC1', 'FC5', 'T7', 'C3', 'CP1', 'CP5',
    'P7', 'P3', 'Pz', 'PO3', 'O1', 'Oz', 'O2', 'PO4', 'P4', 'P8',
    'CP6', 'CP2', 'C4', 'T8', 'FC6', 'FC2', 'F4', 'F8', 'AF4', 'Fp2',
    'Fz', 'Cz']
# band_list=[r'$\theta$', r'$\alpha$', r'$\beta$' , r'$\gamma$']
fig, axes = plt.subplots(figsize=(16, 10), nrows=1, ncols=4)
fig.suptitle('CompareALL')# 'HVLA','LVHA',test-output_layer_
classes = ['LVLA', 'HVLA','LVHA','HVHA']
# 找出所有数据中的最小值和最大值
all_data = [np.load(f'Topo_data/s03_test-output_layer_data{classes[classe]}.npy') for classe in range(4)]
all_data_means = [np.mean(data, axis=1) for data in all_data]
vmin = min([data.min() for data in all_data_means])
vmax = max([data.max() for data in all_data_means])


for classe in range(4):
    data = np.load(f'Topo_data/s03_test-output_layer_data{classes[classe]}.npy')
    print(data)
    info = mne.create_info(ch_names=ch_names, sfreq=128., ch_types='eeg')
    evoked = mne.EvokedArray(data, info)
    evoked.set_montage(biosemi_montage)
    ax=axes[classe]
    mne.viz.plot_topomap(np.mean(evoked.data, axis=1), evoked.info, show=False, axes=ax,
                         ch_type='eeg', cmap='Spectral_r', contours=10, )#vlim=(vmin, vmax),
    ax.set_title(f'{classes[classe]}', fontsize=10)

fig.tight_layout()
plt.show()
# Out:
# [[ 0.04241484  0.02846149  0.34100282 ...  0.19480672 -0.09131384
#   -0.06827467]
#  [ 0.04241484  0.02846149  0.34100282 ...  0.19480672 -0.09131384
#   -0.06827467]
#  [ 0.04241484  0.02846149  0.34100282 ...  0.19480672 -0.09131384
#   -0.06827467]
#  ...
#  [ 0.04241484  0.02846149  0.34100282 ...  0.19480672 -0.09131384
#   -0.06827467]
#  [ 0.04241484  0.02846149  0.34100282 ...  0.19480672 -0.09131384
#   -0.06827467]
#  [ 0.04241484  0.02846149  0.34100282 ...  0.19480672 -0.09131384
#   -0.06827467]]
# [[ 0.04241484  0.02846149  0.34100282 ...  0.19480672 -0.09131384
#   -0.06827467]
#  [ 0.04241484  0.02846149  0.34100282 ...  0.19480672 -0.09131384
#   -0.06827467]
#  [ 0.04241484  0.02846149  0.34100282 ...  0.19480672 -0.09131384
#   -0.06827467]
#  ...
#  [ 0.04241484  0.02846149  0.34100282 ...  0.19480672 -0.09131384
#   -0.06827467]
#  [ 0.04241484  0.02846149  0.34100282 ...  0.19480672 -0.09131384
#   -0.06827467]
#  [ 0.04241484  0.02846149  0.34100282 ...  0.19480672 -0.09131384
#   -0.06827467]]
# [[ 0.07485548 -0.53554916 -0.45506924 ...  0.16084805 -0.34646213
#   -0.426659  ]
#  [ 0.07485548 -0.53554916 -0.45506924 ...  0.16084805 -0.34646213
#   -0.426659  ]
#  [ 0.07485548 -0.53554916 -0.45506924 ...  0.16084805 -0.34646213
#   -0.426659  ]
#  ...
#  [ 0.07485548 -0.53554916 -0.45506924 ...  0.16084805 -0.34646213
#   -0.426659  ]
#  [ 0.07485548 -0.53554916 -0.45506924 ...  0.16084805 -0.34646213
#   -0.426659  ]
#  [ 0.07485548 -0.53554916 -0.45506924 ...  0.16084805 -0.34646213
#   -0.426659  ]]
# [[ 0.07485548 -0.53554916 -0.45506924 ...  0.16084805 -0.34646213
#   -0.426659  ]
#  [ 0.07485548 -0.53554916 -0.45506924 ...  0.16084805 -0.34646213
#   -0.426659  ]
#  [ 0.07485548 -0.53554916 -0.45506924 ...  0.16084805 -0.34646213
#   -0.426659  ]
#  ...
#  [ 0.07485548 -0.53554916 -0.45506924 ...  0.16084805 -0.34646213
#   -0.426659  ]
#  [ 0.07485548 -0.53554916 -0.45506924 ...  0.16084805 -0.34646213
#   -0.426659  ]
#  [ 0.07485548 -0.53554916 -0.45506924 ...  0.16084805 -0.34646213
#   -0.426659  ]]

# %%
biosemi_montage = mne.channels.make_standard_montage('standard_1020')
ch_names = ['Fp1', 'AF3', 'F7', 'F3', 'FC1', 'FC5', 'T7', 'C3', 'CP1', 'CP5',
    'P7', 'P3', 'Pz', 'PO3', 'O1', 'Oz', 'O2', 'PO4', 'P4', 'P8',
    'CP6', 'CP2', 'C4', 'T8', 'FC6', 'FC2', 'F4', 'F8', 'AF4', 'Fp2',
    'Fz', 'Cz']
# band_list=[r'$\theta$', r'$\alpha$', r'$\beta$' , r'$\gamma$']
fig, axes = plt.subplots(figsize=(16, 10), nrows=1, ncols=2)

# 找出所有数据中的最小值和最大值
all_data = [np.load(f'Topo_data/s03_test-output_layer_data{classes[classe]}.npy') for classe in [0,2]]
all_data_means = [np.mean(data, axis=1) for data in all_data]
vmin = min([data.min() for data in all_data_means])
vmax = max([data.max() for data in all_data_means])

classes = ['LVLA', 'HVLA','LVHA','HVHA']
for i, classe in enumerate([0,2]):
    data = np.load(f'Topo_data/s03_test-output_layer_data{classes[classe]}.npy')
    info = mne.create_info(ch_names=ch_names, sfreq=128., ch_types='eeg')
    evoked = mne.EvokedArray(data, info)
    evoked.set_montage(biosemi_montage)
    ax=axes[i]
    im, _ = mne.viz.plot_topomap(np.mean(evoked.data, axis=1), evoked.info, show=False, axes=ax,
                         ch_type='eeg', cmap='Spectral_r', contours=10, vlim=(vmin, vmax),)#vlim=(vmin, vmax),
    ax.set_title(f'{classes[classe]}', fontsize=10)
    
fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.4)
plt.show()

# %%
biosemi_montage = mne.channels.make_standard_montage('standard_1020')
ch_names = ['Fp1', 'AF3', 'F7', 'F3', 'FC1', 'FC5', 'T7', 'C3', 'CP1', 'CP5',
    'P7', 'P3', 'Pz', 'PO3', 'O1', 'Oz', 'O2', 'PO4', 'P4', 'P8',
    'CP6', 'CP2', 'C4', 'T8', 'FC6', 'FC2', 'F4', 'F8', 'AF4', 'Fp2',
    'Fz', 'Cz']
# band_list=[r'$\theta$', r'$\alpha$', r'$\beta$' , r'$\gamma$']
fig, axes = plt.subplots(figsize=(16, 10), nrows=1, ncols=2)

# 找出所有数据中的最小值和最大值
all_data = [np.load(f'Topo_data/s03_test-output_layer_data{classes[classe]}.npy') for classe in [1,3]]
all_data_means = [np.mean(data, axis=1) for data in all_data]
vmin = min([data.min() for data in all_data_means])
vmax = max([data.max() for data in all_data_means])

classes = ['LVLA', 'HVLA','LVHA','HVHA']
for i, classe in enumerate([1,3]):
    data = np.load(f'Topo_data/s03_test-output_layer_data{classes[classe]}.npy')
    info = mne.create_info(ch_names=ch_names, sfreq=128., ch_types='eeg')
    evoked = mne.EvokedArray(data, info)
    evoked.set_montage(biosemi_montage)
    ax=axes[i]
    im, _ = mne.viz.plot_topomap(np.mean(evoked.data, axis=1), evoked.info, show=False, axes=ax,
                         ch_type='eeg', cmap='Spectral_r', contours=10, vlim=(vmin, vmax),)#vlim=(vmin, vmax),
    ax.set_title(f'{classes[classe]}', fontsize=10)
    
fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.4)
plt.show()

# %%
biosemi_montage = mne.channels.make_standard_montage('standard_1020')
ch_names = ['Fp1', 'AF3', 'F7', 'F3', 'FC1', 'FC5', 'T7', 'C3', 'CP1', 'CP5',
    'P7', 'P3', 'Pz', 'PO3', 'O1', 'Oz', 'O2', 'PO4', 'P4', 'P8',
    'CP6', 'CP2', 'C4', 'T8', 'FC6', 'FC2', 'F4', 'F8', 'AF4', 'Fp2',
    'Fz', 'Cz']
# band_list=[r'$\theta$', r'$\alpha$', r'$\beta$' , r'$\gamma$']
fig, axes = plt.subplots(figsize=(16, 10), nrows=1, ncols=2)

# 找出所有数据中的最小值和最大值
all_data = [np.load(f'Topo_data/s03_test-output_layer_data{classes[classe]}.npy') for classe in [2,3]]
all_data_means = [np.mean(data, axis=1) for data in all_data]
vmin = min([data.min() for data in all_data_means])
vmax = max([data.max() for data in all_data_means])

classes = ['LVLA', 'HVLA','LVHA','HVHA']
for i, classe in enumerate([2,3]):
    data = np.load(f'Topo_data/s03_test-output_layer_data{classes[classe]}.npy')
    info = mne.create_info(ch_names=ch_names, sfreq=128., ch_types='eeg')
    evoked = mne.EvokedArray(data, info)
    evoked.set_montage(biosemi_montage)
    ax=axes[i]
    im, _ = mne.viz.plot_topomap(np.mean(evoked.data, axis=1), evoked.info, show=False, axes=ax,
                         ch_type='eeg', cmap='Spectral_r', contours=10, vlim=(vmin, vmax),)#vlim=(vmin, vmax),
    ax.set_title(f'{classes[classe]}', fontsize=10)
    
fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.4)
plt.show()

# %%
biosemi_montage = mne.channels.make_standard_montage('standard_1020')
ch_names = ['Fp1', 'AF3', 'F7', 'F3', 'FC1', 'FC5', 'T7', 'C3', 'CP1', 'CP5',
    'P7', 'P3', 'Pz', 'PO3', 'O1', 'Oz', 'O2', 'PO4', 'P4', 'P8',
    'CP6', 'CP2', 'C4', 'T8', 'FC6', 'FC2', 'F4', 'F8', 'AF4', 'Fp2',
    'Fz', 'Cz']
# band_list=[r'$\theta$', r'$\alpha$', r'$\beta$' , r'$\gamma$']
fig, axes = plt.subplots(figsize=(16, 10), nrows=1, ncols=2)

# # 找出所有数据中的最小值和最大值
# all_data = [np.load(f'Topo_data/s03_test-output_layer_data{classes[classe]}.npy') for classe in [0,1]]
# all_data_means = [np.mean(data, axis=1) for data in all_data]
# vmin = min([data.min() for data in all_data_means])
# vmax = max([data.max() for data in all_data_means])

classes = ['LVLA', 'HVLA','LVHA','HVHA']
for i, classe in enumerate([0,1]):
    print(classes[classe])
    data = np.load(f'Topo_data/s03_test-output_layer_data{classes[classe]}.npy')
    print(data)
    info = mne.create_info(ch_names=ch_names, sfreq=128., ch_types='eeg')
    evoked = mne.EvokedArray(data, info)
    evoked.set_montage(biosemi_montage)
    ax=axes[i]
    im, _ = mne.viz.plot_topomap(np.mean(evoked.data, axis=1), evoked.info, show=False, axes=ax,
                         ch_type='eeg', cmap='Spectral_r', contours=10, vlim=(vmin, vmax),)#vlim=(vmin, vmax),
    ax.set_title(f'{classes[classe]}', fontsize=10)
    
fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.4)
plt.show()
# Out:
# LVLA
# [[ 0.22565149  0.74075264  1.4123092  ...  0.17779747  0.45307904
#    0.49704635]
#  [ 0.19882432 -0.01521205 -0.02969068 ...  0.3053871   0.40712857
#   -0.0301813 ]
#  [ 0.7076963   2.5028496   3.34701    ...  1.3853117   2.3740482
#    0.6970266 ]
#  ...
#  [ 1.2540097   0.06474587  2.4875798  ...  2.2119558   3.5135775
#    1.0501128 ]
#  [ 0.584312    0.0755365  -0.0186315  ...  0.09413087  0.7449984
#   -0.02491874]
#  [ 0.663942    0.17534205  0.7530909  ... -0.0368475   1.184893
#    1.1428523 ]]
# HVLA
# [[ 0.22565149  0.74075264  1.4123092  ...  0.17779747  0.45307904
#    0.49704635]
#  [ 0.19882432 -0.01521205 -0.02969068 ...  0.3053871   0.40712857
#   -0.0301813 ]
#  [ 0.7076963   2.5028496   3.34701    ...  1.3853117   2.3740482
#    0.6970266 ]
#  ...
#  [ 1.2540097   0.06474587  2.4875798  ...  2.2119558   3.5135775
#    1.0501128 ]
#  [ 0.584312    0.0755365  -0.0186315  ...  0.09413087  0.7449984
#   -0.02491874]
#  [ 0.663942    0.17534205  0.7530909  ... -0.0368475   1.184893
#    1.1428523 ]]

# %%
HVHA=np.load('output_layer_data4.npy')

# %%
biosemi_montage = mne.channels.make_standard_montage('standard_1020')
ch_names = ['Fp1', 'AF3', 'F7', 'F3', 'FC1', 'FC5', 'T7', 'C3', 'CP1', 'CP5',
    'P7', 'P3', 'Pz', 'PO3', 'O1', 'Oz', 'O2', 'PO4', 'P4', 'P8',
    'CP6', 'CP2', 'C4', 'T8', 'FC6', 'FC2', 'F4', 'F8', 'AF4', 'Fp2',
    'Fz', 'Cz']
# band_list=[r'$\theta$', r'$\alpha$', r'$\beta$' , r'$\gamma$']
# fig, axes = plt.subplots(figsize=(16, 10), nrows=4, ncols=4)

# vlim = (feature.min(), feature.max())
# classes = ['LVLA', 'HVLA','LVHA','HVHA']
# for classe in range(4):
#     for i, ax in enumerate(axes[classe]):  # iterate over bands (columns) within each class
info = mne.create_info(ch_names=ch_names, sfreq=128., ch_types='eeg')
evoked = mne.EvokedArray(HVHA, info)
evoked.set_montage(biosemi_montage)
mne.viz.plot_topomap(np.mean(evoked.data, axis=1), evoked.info, show=False, 
                     ch_type='eeg', cmap='Spectral_r', contours=10)
# Out:
# (<matplotlib.image.AxesImage at 0x1273e2230>,
#  <matplotlib.contour.QuadContourSet at 0x1273e26b0>)

# %%
HVLA=np.load('output_layer_data3.npy')

# %%
biosemi_montage = mne.channels.make_standard_montage('standard_1020')
ch_names = ['Fp1', 'AF3', 'F7', 'F3', 'FC1', 'FC5', 'T7', 'C3', 'CP1', 'CP5',
    'P7', 'P3', 'Pz', 'PO3', 'O1', 'Oz', 'O2', 'PO4', 'P4', 'P8',
    'CP6', 'CP2', 'C4', 'T8', 'FC6', 'FC2', 'F4', 'F8', 'AF4', 'Fp2',
    'Fz', 'Cz']
# band_list=[r'$\theta$', r'$\alpha$', r'$\beta$' , r'$\gamma$']
# fig, axes = plt.subplots(figsize=(16, 10), nrows=4, ncols=4)

# vlim = (feature.min(), feature.max())
# classes = ['LVLA', 'HVLA','LVHA','HVHA']
# for classe in range(4):
#     for i, ax in enumerate(axes[classe]):  # iterate over bands (columns) within each class
info = mne.create_info(ch_names=ch_names, sfreq=128., ch_types='eeg')
evoked = mne.EvokedArray(HVLA, info)
evoked.set_montage(biosemi_montage)
mne.viz.plot_topomap(np.mean(evoked.data, axis=1), evoked.info, show=False, 
                     ch_type='eeg', cmap='Spectral_r', contours=10)
# Out:
# (<matplotlib.image.AxesImage at 0x1275d88b0>,
#  <matplotlib.contour.QuadContourSet at 0x1275d8d30>)

# %%
LVHA=np.load('output_layer_dataLAHV.npy')

# %%
biosemi_montage = mne.channels.make_standard_montage('standard_1020')
ch_names = ['Fp1', 'AF3', 'F7', 'F3', 'FC1', 'FC5', 'T7', 'C3', 'CP1', 'CP5',
    'P7', 'P3', 'Pz', 'PO3', 'O1', 'Oz', 'O2', 'PO4', 'P4', 'P8',
    'CP6', 'CP2', 'C4', 'T8', 'FC6', 'FC2', 'F4', 'F8', 'AF4', 'Fp2',
    'Fz', 'Cz']
# band_list=[r'$\theta$', r'$\alpha$', r'$\beta$' , r'$\gamma$']
# fig, axes = plt.subplots(figsize=(16, 10), nrows=4, ncols=4)

# vlim = (feature.min(), feature.max())
# classes = ['LVLA', 'HVLA','LVHA','HVHA']
# for classe in range(4):
#     for i, ax in enumerate(axes[classe]):  # iterate over bands (columns) within each class
info = mne.create_info(ch_names=ch_names, sfreq=128., ch_types='eeg')
evoked = mne.EvokedArray(LVHA, info)
evoked.set_montage(biosemi_montage)
mne.viz.plot_topomap(np.mean(evoked.data, axis=1), evoked.info, show=False, 
                     ch_type='eeg', cmap='Spectral_r', contours=10)
# Out:
# (<matplotlib.image.AxesImage at 0x12764e4d0>,
#  <matplotlib.contour.QuadContourSet at 0x12764e950>)
